# %%
import pandas as pd
import sys
import numpy as np
import json

# %%
archival_info_string = open("archival_info_locations.json", "r").read()
archival_info = json.loads(archival_info_string)

# %%
def get_locations(invno):
    
    try:
        locations = archival_info[str(invno)]['locations']
        output = ''
        for x in locations:
            output = output + ';' + x
        
        return output.strip(';')
    
    except KeyError:
        return " "

# %%
def build_mapping(df):
    output = {}
    for i, row in df.iterrows():
        output[df.loc[i, "File Name"]] = df.loc[i, "inv_no"]
        
    return output

# %%
def clean_nan_rows(df):
    condition = df.iloc[:, 1].apply(identify_document_name_rows) & df.iloc[:, 2:].isna().all(axis=1)
    output = df[~condition]
    return output

# %%
def identify_document_name_rows(cell):
    #easiest marker right now is the .png filename
    if type(cell) == str:
        if type(cell) == float:
            return False
        elif '.png' in cell:
            return True
        elif '.jpg' in cell:
            return True
        else:
            return False

# %%
def safe_split_page_nos(row):
    """ Wrapper to handle potential unpacking issues """
    try:
        start, end = split_page_nos(row)
        return start, end
    except Exception as e:
        print(f"Error processing row: {row}, Error: {e}")
        return None, None  # Return a safe default

# %%
def rename_col_by_index(dataframe, index_mapping):
    dataframe.columns = [index_mapping.get(i, col) for i, col in enumerate(dataframe.columns)]
    return dataframe

# %%
def add_invno(value, png_mapping):
    return png_mapping[value]

# %%
def main():
    #read the excel file
    df = pd.read_excel("TANAP merged/gen geo coverage.xlsx")
    
    #remove any rows that don't contain information other than the scan title
       
    #add locations
    df['GEOGRAPHICAL COVERAGE OF INV. NUMBER'] = df['INVENTORY NUMBER'].apply(get_locations)
    
    df.to_excel('tanap geo coverage.xlsx')
    
    return df

# %%
mapping_df = build_mapping(pd.read_csv('png_mapping.csv'))

# %%
#add_invno('224313.1_NL-HaNA_2.14.03_2461-14_contrast.png', mapping_df)

# %%
def split_page_nos(cell):
    dividers = [' a ', '-', '—']
    
    if isinstance(cell, str):
        found = False
        for divider in dividers:
            if divider in cell:
                found = True
                parts = [part.strip() for part in cell.split(divider)]
                # Ensure there are exactly two parts after splitting
                if len(parts) == 2:
                    start_page, end_page = parts
                else:
                    # Fallback if there's unexpected behavior
                    start_page = end_page = str(cell)
                break
        else:
            # No divider was found, use the cell itself
            start_page = end_page = str(cell)
    else:
        start_page = end_page = str(cell)
    
    return start_page, end_page

# %%
main()
# Out:
#         ID (TANAP)  ID (GLOBALISE)  \
# 0                1             NaN
# 1                2             NaN
# 2                3             NaN
# 3                4             NaN
# 4                5             NaN
# ...            ...             ...
# 170127      170128             NaN
# 170128      170129             NaN
# 170129      170130             NaN
# 170130      170131             NaN
# 170131      170132             NaN
#
#                                               DESCRIPTION  YEAR (EARLIEST)  \
# 0       Copie verklaringh verleent door de Addeponaers...             1694
# 1       Lijst der te Batavia in 1784 geweest zijnde Ch...             1784
# 2       Resoluties genomen in rade van politie tot Col...             1733
# 3       Copie missive van Jan Dircksz. Lam uijt de bai...             1617
# 4       Extract uijt de consideratien vanden raad ordi...             1738
# ...                                                   ...              ...
# 170127  Duplicaat register der verzondene papieren met...             1786
# 170128  Copia registers met de schepen Texelstroom en ...             1786
# 170129  Lijst van de officieren en passagiers met het ...             1787
# 170130  Origineele missive van hunne hoogedelheeden aa...             1787
# 170131  Zes pees rendementen van sodanige coopmanschap...             1767
#
#         YEAR (LATEST) YEARS (ALL)           SETTLEMENT  \
# 0                1694        1694               Ceylon
# 1                1784        1784              Batavia
# 2                1733        1733               Ceylon
# 3                1617        1617  Azië, plaatsen in -
# 4                1739   1738|1739           Coromandel
# ...               ...         ...                  ...
# 170127           1786        1786              Batavia
# 170128           1786        1786              Batavia
# 170129           1787        1787              Batavia
# 170130           1787        1787              Batavia
# 170131           1768   1767|1768               Bantam
#
#                        LOCATION  \
# 0       Tutucorin|Jaffanapatnam
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 170127                      NaN
# 170128                      NaN
# 170129                      NaN
# 170130                      NaN
# 170131                      NaN
#
#                      GEOGRAPHICAL COVERAGE OF INV. NUMBER  INVENTORY NUMBER  \
# 0                                                  Ceylon              1543
# 1                                                 Batavia              3656
# 2                                                                      8959
# 3                                                                      1064
# 4                                     Bengalen;Coromandel              2489
# ...                                                   ...               ...
# 170127                                                                 7590
# 170128                                                                 7590
# 170129                                                                 7590
# 170130                                                                 7590
# 170131  Japan;Java;Makassar;Oostkust;Palembang;Ternate...              3248
#
#        SECTION  FOLIONUMBER (START OF DOCUMENT)  \
# 0          NaN                              697
# 1          NaN                              978
# 2          NaN                              438
# 3          NaN                              143
# 4          NaN                              479
# ...        ...                              ...
# 170127     NaN                              789
# 170128     NaN                              793
# 170129     NaN                              799
# 170130     NaN                              803
# 170131     NaN                              205
#
#         FOLIONUMBER (END OF DOCUMENT)  \
# 0                                 698
# 1                                 979
# 2                                 471
# 3                                 144
# 4                                 485
# ...                               ...
# 170127                            791
# 170128                            798
# 170129                            801
# 170130                            807
# 170131                            207
#
#         FOLIONUMBERS (AS THEY APPEAR IN TYPOSCRIPT)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 170127                                          NaN
# 170128                                          NaN
# 170129                                          NaN
# 170130                                          NaN
# 170131                                          NaN
#
#                                             DOCUMENT TYPE  \
# 0       RUBRIEK:Brieven, rapporten en instructies verz...
# 1       RUBRIEK:Stukken betreffende schepen en equipag...
# 2       RUBRIEK:Brieven, rapporten en instructies verz...
# 3       RUBRIEK:Overige brieven, rapporten en instruct...
# 4       RUBRIEK:Overige brieven, rapporten en instruct...
# ...                                                   ...
# 170127  RUBRIEK:Brieven, rapporten en instructies ontv...
# 170128  RUBRIEK:Brieven, rapporten en instructies ontv...
# 170129  RUBRIEK:Stukken betreffende personeel en bevol...
# 170130  RUBRIEK:Brieven, rapporten en instructies ontv...
# 170131  RUBRIEK:Stukken betreffende boekhouding en fin...
#
#                                                    LINK-2  \
# 0       NL-HaNA/1.04.02/1543///Katern: Ceylon  Pagina ...
# 1       NL-HaNA/1.04.02/3656///Katern: Batavia  Pagina...
# 2       NL-HaNA/1.04.02/8959///Katern: Ceylon  Pagina ...
# 3       NL-HaNA/1.04.02/1064///Katern: Azië, plaatsen ...
# 4       NL-HaNA/1.04.02/2489///Katern: Coromandel  Pag...
# ...                                                   ...
# 170127  NL-HaNA/1.04.02/7590///Katern: Batavia  Pagina...
# 170128  NL-HaNA/1.04.02/7590///Katern: Batavia  Pagina...
# 170129  NL-HaNA/1.04.02/7590///Katern: Batavia  Pagina...
# 170130  NL-HaNA/1.04.02/7590///Katern: Batavia  Pagina...
# 170131  NL-HaNA/1.04.02/3248///Katern: Bantam  Pagina ...
#
#                                         LINK
# 0       244ea5cc-9aed-102e-9032-0050569c51dd
# 1       47deaf06-b00e-102e-9c8f-0050569c51dd
# 2       47f794e4-b00e-102e-9c8f-0050569c51dd
# 3       481869c6-b00e-102e-9c8f-0050569c51dd
# 4       482c310e-b00e-102e-9c8f-0050569c51dd
# ...                                      ...
# 170127  89205aca-ab66-102e-8314-0050569c51dd
# 170128  89206236-ab66-102e-8314-0050569c51dd
# 170129  892069c0-ab66-102e-8314-0050569c51dd
# 170130  89207154-ab66-102e-8314-0050569c51dd
# 170131  89207884-ab66-102e-8314-0050569c51dd
#
# [170132 rows x 17 columns]
